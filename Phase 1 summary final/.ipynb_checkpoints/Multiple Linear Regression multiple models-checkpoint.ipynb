# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

# %%
df = pd.read_csv('Amreli NRM data for model building2.csv')
df.columns
# Out:
# Index(['campaign', 'Heat number (life number)',
#        'Total Heat Time previous (minutes)', 'Total Heat Time (minutes)',
#        'Scrap (MT)', 'Sponge (MT)', 'Hot Heel (MT)', 'Alloys (MT)',
#        'Previous Input (MT)', 'Input (MT)', 'Final C%',
#        'Tapping Temperature (C)', 'Previous Output (MT)', 'Output (MT)',
#        'Input energy previous (KWH)', 'Input energy (KWH)', 'Previous Voltage',
#        'Previous Frequency', 'Previous Rating of the Furnace', 'Voltage',
#        'Frequency', 'Rating of the furnace (KW)', 'Melt rate (MT/Hr)',
#        'Efficiency (MT/KWH)', 'Number of capacitors removed',
#        'Refractory lining before heating', 'Refractory lining after heating',
#        'Inverse Efficiency (KWH/MT)', 'Power', 'Power previous'],
#       dtype='object')

# %%
campaign = np.unique(df['campaign'])

for c in campaign:
    dfc = df[df['campaign']==c]
    i = dfc.index[0]
    df = df.drop(i)
    
df = df.reset_index(drop=True)
df['Number of capacitors removed'].fillna(0, inplace=True)
threshold = 150

for i in range(df.shape[0]):
    if(df.loc[i,'Total Heat Time previous (minutes)']>threshold):
        df.loc[i,'Total Heat Time previous (minutes)']= threshold
    if(df.loc[i,'Total Heat Time (minutes)']>threshold):
        df.loc[i,'Total Heat Time (minutes)']= threshold
        
df['Input energy previous (KWH)'] = df['Power previous']*df['Total Heat Time previous (minutes)']/60
df['Input energy (KWH)'] = df['Power']*df['Total Heat Time (minutes)']/60

# %%
df['Voltage'].describe()
# Out:
# count     440.000000
# mean     3560.813636
# std       171.152683
# min      3063.000000
# 25%      3402.750000
# 50%      3580.000000
# 75%      3744.000000
# max      3770.000000
# Name: Voltage, dtype: float64

# %%
df['Input energy (KWH)']
# Out:
# 0      45708.750000
# 1      37250.000000
# 2      29406.666667
# 3      33259.916667
# 4      29659.000000
#            ...
# 435    39504.833333
# 436    28407.500000
# 437    26759.250000
# 438    48270.500000
# 439    29146.333333
# Name: Input energy (KWH), Length: 440, dtype: float64

# %%
input_columns = ['Scrap (MT)', 'Sponge (MT)', 'Hot Heel (MT)', 'Alloys (MT)','Previous Input (MT)','Previous Voltage', 'Total Heat Time previous (minutes)',
                 'Previous Frequency','Previous Rating of the Furnace','Previous Output (MT)', 'Refractory lining before heating','Number of capacitors removed','Tapping Temperature (C)','Input energy previous (KWH)']
# output_columns = ['Inverse Efficiency (KWH/MT)','Total Heat Time (minutes)','Voltage','Frequency','Refractory lining after heating']
output_columns = ['Voltage','Frequency','Refractory lining after heating']

X = df[input_columns]
X_train = X.iloc[:318,:].values
X_test = X.iloc[318:,:].values
y = df[output_columns]
y_train = y.iloc[:318,:].values
y_test = y.iloc[318:,:].values

lr = LinearRegression()
lr.fit(X_train, y_train)
y_pred_train = lr.predict(X_train)
y_pred_test = lr.predict(X_test)

for i in range(3):
    print(output_columns[i])
    print("Train score is {}".format(mean_squared_error(y_train[:,i], y_pred_train[:,i])))
    print("Test score is {}".format(mean_squared_error(y_test[:,i], y_pred_test[:,i])))
    print("R2 score is {}".format(r2_score(y_test[:,i], y_pred_test[:,i])))
    print("Train NMSE score is {}".format(np.sum(np.square(y_pred_train[:,i]-y_train[:,i]))/np.sum(np.square(y_train[:,i]-np.mean(y_train[:,i])))*100))
    print("Test NMSE score is {}".format(np.sum(np.square(y_pred_test[:,i]-y_test[:,i]))/np.sum(np.square(y_test[:,i]-np.mean(y_test[:,i])))*100))

for i in range(lr.coef_.shape[0]):
    for j in range(lr.coef_.shape[1]):
        print("Weight of {} on {} is {}".format(input_columns[j], output_columns[i],lr.coef_[i][j]))
    print('\n')
# Out:
# Voltage
# Train score is 5295.652045389165
# Test score is 4970.4846643132205
# R2 score is 0.8536957738549005
# Train NMSE score is 19.336936508888204
# Test NMSE score is 14.630422614509955
# Frequency
# Train score is 24.902732082247933
# Test score is 34.390054509873714
# R2 score is 0.9569968011648818
# Train NMSE score is 3.053617318949126
# Test NMSE score is 4.300319883511814
# Refractory lining after heating
# Train score is 5.3534188049512607e-05
# Test score is 0.00015821507202286309
# R2 score is 0.9997556153790689
# Train NMSE score is 0.00836139067293427
# Test NMSE score is 0.024438462093109684
# Weight of Scrap (MT) on Voltage is -7.45480291910635
# Weight of Sponge (MT) on Voltage is -5.24266072997032
# Weight of Hot Heel (MT) on Voltage is 2.638778084929072e-12
# Weight of Alloys (MT) on Voltage is -70.11007024975403
# Weight of Previous Input (MT) on Voltage is 2.6040373424953915
# Weight of Previous Voltage on Voltage is 0.3330520244664561
# Weight of Total Heat Time previous (minutes) on Voltage is -0.04183524928546361
# Weight of Previous Frequency on Voltage is -1.9540419533774427
# Weight of Previous Rating of the Furnace on Voltage is 0.33305202446670124
# Weight of Previous Output (MT) on Voltage is 1.5030946297120233
# Weight of Refractory lining before heating on Voltage is 57.939280840082404
# Weight of Number of capacitors removed on Voltage is 25.40186382150727
# Weight of Tapping Temperature (C) on Voltage is -0.040971837246090465
# Weight of Input energy previous (KWH) on Voltage is 0.0020383688539205025
#
#
# Weight of Scrap (MT) on Frequency is 1.2201647203253385
# Weight of Sponge (MT) on Frequency is 1.0095720033370046
# Weight of Hot Heel (MT) on Frequency is -2.5118795932144167e-13
# Weight of Alloys (MT) on Frequency is 6.805254545304629
# Weight of Previous Input (MT) on Frequency is -0.8371294928007302
# Weight of Previous Voltage on Frequency is -0.0024533772856319552
# Weight of Total Heat Time previous (minutes) on Frequency is 0.005541103464928508
# Weight of Previous Frequency on Frequency is 0.39244102081601084
# Weight of Previous Rating of the Furnace on Frequency is -0.0024533772856586006
# Weight of Previous Output (MT) on Frequency is 0.7156895212985205
# Weight of Refractory lining before heating on Frequency is -3.2872070988873205
# Weight of Number of capacitors removed on Frequency is 5.9286812523044325
# Weight of Tapping Temperature (C) on Frequency is -0.0027816249011640773
# Weight of Input energy previous (KWH) on Frequency is 7.387338781073005e-05
#
#
# Weight of Scrap (MT) on Refractory lining after heating is -0.0003516975708659054
# Weight of Sponge (MT) on Refractory lining after heating is -0.000522340107181177
# Weight of Hot Heel (MT) on Refractory lining after heating is 4.649058915617843e-16
# Weight of Alloys (MT) on Refractory lining after heating is 0.0002425003263769396
# Weight of Previous Input (MT) on Refractory lining after heating is 0.00029890381230007247
# Weight of Previous Voltage on Refractory lining after heating is 1.0852812648646206e-05
# Weight of Total Heat Time previous (minutes) on Refractory lining after heating is 6.223091314432028e-05
# Weight of Previous Frequency on Refractory lining after heating is -0.00034820859928926337
# Weight of Previous Rating of the Furnace on Refractory lining after heating is 1.0852812649546528e-05
# Weight of Previous Output (MT) on Refractory lining after heating is -0.00012992092956867974
# Weight of Refractory lining before heating on Refractory lining after heating is 0.9899730279337132
# Weight of Number of capacitors removed on Refractory lining after heating is 0.0016604594738190866
# Weight of Tapping Temperature (C) on Refractory lining after heating is -1.676760305273333e-06
# Weight of Input energy previous (KWH) on Refractory lining after heating is -2.7223376453740407e-07

# %%
for i in range(3):
    plt.scatter(y_train[:,i], y_pred_train[:,i], c='b');
    plt.xlabel('Training data')
    plt.ylabel('Predicted value')
    plt.title('Training data vs Prediction')
    plt.show()
    plt.scatter(y_test[:,i], y_pred_test[:,i], c='r');
    plt.xlabel('Test data')
    plt.ylabel('Predicted value')
    plt.title('Test data vs Prediction')
    plt.show()

# %%
import pickle
pickle.dump(lr, open('D:\customerdatacompilation\Models\lin_model.pkl', 'wb'))

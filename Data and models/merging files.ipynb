# %%
import numpy as np
import pandas as pd

# %%
df1 = pd.read_csv("Amreli nrm.csv")
df1 = df1.iloc[:449,:]
df1
# Out:
#      Heat number (life number)  Total Heat Time (minutes)  Scrap (MT)  \
# 0                          1.0                      130.0         0.0
# 1                          2.0                      135.0        11.0
# 2                          3.0                      125.0        12.0
# 3                          4.0                      110.0        12.0
# 4                          5.0                      115.0        13.0
# 5                          6.0                      105.0        15.0
# 6                          7.0                      115.0        16.0
# 7                          8.0                      125.0        19.0
# 8                          9.0                      120.0        17.0
# 9                         10.0                      130.0        14.0
# 10                        11.0                      130.0        15.0
# 11                        12.0                      120.0        17.0
# ...

# %%
df1['Hot Heel (MT)'] = 0

# %%
df1
# Out:
#      Heat number (life number)  Total Heat Time (minutes)  Scrap (MT)  \
# 0                          1.0                      130.0         0.0
# 1                          2.0                      135.0        11.0
# 2                          3.0                      125.0        12.0
# 3                          4.0                      110.0        12.0
# 4                          5.0                      115.0        13.0
# 5                          6.0                      105.0        15.0
# 6                          7.0                      115.0        16.0
# 7                          8.0                      125.0        19.0
# 8                          9.0                      120.0        17.0
# 9                         10.0                      130.0        14.0
# 10                        11.0                      130.0        15.0
# 11                        12.0                      120.0        17.0
# ...

# %%
df2 = pd.read_csv("MSP nrm.csv")

# %%
df2
# Out:
#     Heat number (life number)  Total Heat Time (minutes)  Scrap (MT)  \
# 0                           1                      365.0       3.500
# 1                           2                      180.0       2.100
# 2                           3                      175.0       0.800
# 3                           4                      170.0       0.175
# 4                           5                      160.0       0.150
# 5                           6                      165.0       0.150
# 6                           7                      160.0       0.125
# 7                           8                      145.0       0.125
# 8                           9                      160.0       0.125
# 9                          10                      155.0       0.125
# 10                         11                      150.0       0.125
# 11                         12                      145.0       0.125
# 12                         13                      160.0       0.125
# ...

# %%
df3 = pd.concat([df1,df2], ignore_index=True)

# %%
df3
# Out:
#      Heat number (life number)  Total Heat Time (minutes)  Scrap (MT)  \
# 0                            1                      130.0       0.000
# 1                            2                      135.0      11.000
# 2                            3                      125.0      12.000
# 3                            4                      110.0      12.000
# 4                            5                      115.0      13.000
# 5                            6                      105.0      15.000
# 6                            7                      115.0      16.000
# 7                            8                      125.0      19.000
# 8                            9                      120.0      17.000
# 9                           10                      130.0      14.000
# 10                          11                      130.0      15.000
# 11                          12                      120.0      17.000
# ...

# %%
df3.to_csv("Amreli and MSP NRM data.csv",index=False)
